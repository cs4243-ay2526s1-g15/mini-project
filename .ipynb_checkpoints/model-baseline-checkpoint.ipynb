# %% [markdown]
# # Baseline CNN model - High level Architecture

# %%
# imports
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import seaborn as sns
from sklearn.metrics import confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# # Baseline CNN model - High level Architecture
#
# ## Functions
# - `tokenise_image()`: Splits an image into at most 8 distinct subimages of 80x80 pixels. This is done by checking column by column and cutting the image at all-white columns after non-white columns (character ends). Check if the number of subimages is equal to the number of label characters, else throw them out.
# - `build_dataset()`: Builds a character-by-character training set from the images.
# - `build_cnn_model()`: Builds the baseline CNN model, output is a single one-hot classification vector of 36 possible categorical values (`a-z0-9`).
# - `predict_image()`: takes an image, tokenises it, runs each subimage into the CNN model, comes out with <=8 outputs and labels, compare with the original label.

# %%
# Assumes image has already been imported as a grayscale OpenCV image
def tokenise_image(img):
  min_width = 3

  # sum columns of image
  col_sum = np.sum(img, axis=0)

  # detect character start and end indices
  splits = []
  in_char = False
  start = 0
  for i, val in enumerate(col_sum):
    if not in_char and val < 20400:  # start of character
      in_char = True
      start = i
    elif in_char and val == 20400:  # end of character
      in_char = False
      end = i
      if end - start > min_width:
        splits.append((start, end))

  # handle edge case: last char till end
  if in_char:
    splits.append((start, len(col_sum)))

  # crop each detected region
  chars = []
  for (start, end) in splits:
    # this is the trimmed image. guaranteed to have a height of 80.
    char_img = img[:, start:end]
    
    # pad to make square (80x80)
    h, w = char_img.shape
    padded = np.ones((80, 80), dtype=np.uint8) * 255
    scale = 76 / max(h, w)
    resized = cv2.resize(char_img, (int(w * scale), int(h * scale)))
    ph, pw = resized.shape
    padded[(80 - ph)//2:(80 - ph)//2 + ph, (80 - pw)//2:(80 - pw)//2 + pw] = resized
    chars.append(padded)
    
  return chars

def show_tokenised(chars):
    plt.figure(figsize=(len(chars)*2, 2))  # adjust width dynamically
    for i, c in enumerate(chars):
        plt.subplot(1, len(chars), i + 1)
        plt.imshow(c, cmap='gray')
        plt.axis('off')
    plt.show()

# %%
# Example of tokenising an image
image_name = "0a1gfi"
test_image = cv2.imread(f"./train/{image_name}-0.png", cv2.IMREAD_GRAYSCALE)
tokenised_images = tokenise_image(test_image)
plt.imshow(test_image, cmap='gray')
plt.axis('off')   # hide axes
plt.show()

show_tokenised(tokenised_images)

# %%
# Helper functions to assign each letter and digit to label numbers

CHARSET = "abcdefghijklmnopqrstuvwxyz0123456789"

char_to_idx = {ch: idx for idx, ch in enumerate(CHARSET)}
idx_to_char = {idx: ch for idx, ch in enumerate(CHARSET)}

# encodes character to the 36-character set
def encode(character):
  return char_to_idx[character.lower()]

def decode(character):
  return idx_to_char[character]

encode_array = np.vectorize(encode)
decode_array = np.vectorize(decode)

print(encode("a"), encode("z"), encode("0"), encode("9"))
print(encode("y")) # 24
print(encode("6")) # 32
print(decode(17)) # r
print(decode(34)) # 8
print(encode_array(np.array(["a", "z", "0", "9"])))
print(decode_array(np.array([0, 25, 26, 35])))
# Out:
# 0 25 26 35
# 24
# 32
# r
# 8
# [ 0 25 26 35]
# ['a' 'z' '0' '9']

# %%
def build_training_dataset(train_dir = "./train"):
  image_files = [f for f in os.listdir(train_dir) if f.lower().endswith((".png"))]

  X = []
  y = []
  lengths = []

  for fname in image_files:
    # Split at '-' to isolate the captcha text
    label = fname.split('-')[0]

    image = cv2.imread(f"{train_dir}/{fname}", cv2.IMREAD_GRAYSCALE)

    tokenised_images = tokenise_image(image)
    if len(label) == len(tokenised_images):
      for i in range(len(label)):
        X.append(tokenised_images[i])
        y.append(label[i])
      lengths.append(len(label))

  X = np.array(X)
  X = X[..., np.newaxis]
  X = X.astype("float32") / 255.0
  y = np.array(y)

  y_encoded = encode_array(y)

  y_onehot = to_categorical(y_encoded, num_classes=36)

  return X, y_onehot, lengths

X_train, y_train, lengths_train = build_training_dataset()
X_test, y_test, lengths_test = build_training_dataset("./test")
print(X_train.shape, y_train.shape, len(lengths_train))
print(X_test.shape, y_test.shape, len(lengths_test))
# Out:
# (40160, 80, 80, 1) (40160, 36) 6745
# (10083, 80, 80, 1) (10083, 36) 1694

# %%
def build_cnn_model(input_shape=(80, 80, 1)):
    inputs = Input(shape = input_shape)

    x = Conv2D(32, 3, activation='relu', padding='same')(inputs)
    x = MaxPooling2D(2)(x)

    x = Conv2D(64, 3, activation='relu', padding='same')(x)
    x = MaxPooling2D(2)(x)

    x = Conv2D(128, 3, activation='relu', padding='same')(x)
    x = MaxPooling2D(2)(x)

    # x = Conv2D(256, 3, activation='relu', padding='same')(x)
    # x = MaxPooling2D(2)(x)

    # resulting shape: (10, 10, 128)

    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.4)(x)
    outputs = Dense(36, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=outputs)

    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
# build CAPTCHA CNN
model = build_cnn_model()

callbacks=[
  EarlyStopping(monitor='val_accuracy', patience=12, mode='max', restore_best_weights=True),
  ReduceLROnPlateau(factor=0.5, patience=5)
]

# train model on training data
history = model.fit(
  X_train,
  y_train,
  validation_data=(X_test, y_test),
  epochs=80,
  batch_size=32,
  callbacks=callbacks
)

# save model
model.save("captcha_cnn_model.keras")
# Out:
# Epoch 1/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 125s 97ms/step - accuracy: 0.2940 - loss: 2.4996 - val_accuracy: 0.6185 - val_loss: 1.3858 - learning_rate: 0.0010
# Epoch 2/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 121s 96ms/step - accuracy: 0.5545 - loss: 1.4705 - val_accuracy: 0.7007 - val_loss: 1.0338 - learning_rate: 0.0010
# Epoch 3/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 123s 98ms/step - accuracy: 0.6159 - loss: 1.2407 - val_accuracy: 0.7287 - val_loss: 0.9352 - learning_rate: 0.0010
# Epoch 4/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 123s 98ms/step - accuracy: 0.6594 - loss: 1.0942 - val_accuracy: 0.7556 - val_loss: 0.8138 - learning_rate: 0.0010
# Epoch 5/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 125s 99ms/step - accuracy: 0.6886 - loss: 0.9856 - val_accuracy: 0.7730 - val_loss: 0.7629 - learning_rate: 0.0010
# Epoch 6/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 122s 98ms/step - accuracy: 0.7082 - loss: 0.9146 - val_accuracy: 0.7771 - val_loss: 0.7513 - learning_rate: 0.0010
# Epoch 7/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 124s 99ms/step - accuracy: 0.7239 - loss: 0.8596 - val_accuracy: 0.7884 - val_loss: 0.7218 - learning_rate: 0.0010
# Epoch 8/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 126s 100ms/step - accuracy: 0.7384 - loss: 0.7995 - val_accuracy: 0.7958 - val_loss: 0.6986 - learning_rate: 0.0010
# Epoch 9/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 125s 99ms/step - accuracy: 0.7545 - loss: 0.7610 - val_accuracy: 0.8022 - val_loss: 0.6949 - learning_rate: 0.0010
# Epoch 10/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 128s 102ms/step - accuracy: 0.7646 - loss: 0.7110 - val_accuracy: 0.7982 - val_loss: 0.6996 - learning_rate: 0.0010
# Epoch 11/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 125s 100ms/step - accuracy: 0.7724 - loss: 0.6834 - val_accuracy: 0.8077 - val_loss: 0.6655 - learning_rate: 0.0010
# Epoch 12/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 125s 99ms/step - accuracy: 0.7823 - loss: 0.6484 - val_accuracy: 0.8056 - val_loss: 0.6912 - learning_rate: 0.0010
# Epoch 13/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 125s 100ms/step - accuracy: 0.7884 - loss: 0.6335 - val_accuracy: 0.8168 - val_loss: 0.6519 - learning_rate: 0.0010
# Epoch 14/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 125s 99ms/step - accuracy: 0.7933 - loss: 0.6064 - val_accuracy: 0.8225 - val_loss: 0.6534 - learning_rate: 0.0010
# Epoch 15/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 124s 99ms/step - accuracy: 0.7993 - loss: 0.5871 - val_accuracy: 0.8190 - val_loss: 0.6619 - learning_rate: 0.0010
# Epoch 16/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 125s 99ms/step - accuracy: 0.8110 - loss: 0.5581 - val_accuracy: 0.8267 - val_loss: 0.6449 - learning_rate: 0.0010
# Epoch 17/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 128s 102ms/step - accuracy: 0.8152 - loss: 0.5355 - val_accuracy: 0.8186 - val_loss: 0.6654 - learning_rate: 0.0010
# Epoch 18/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 126s 100ms/step - accuracy: 0.8157 - loss: 0.5302 - val_accuracy: 0.8263 - val_loss: 0.6910 - learning_rate: 0.0010
# Epoch 19/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 126s 100ms/step - accuracy: 0.8246 - loss: 0.5075 - val_accuracy: 0.8316 - val_loss: 0.6780 - learning_rate: 0.0010
# Epoch 20/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 126s 101ms/step - accuracy: 0.8293 - loss: 0.4923 - val_accuracy: 0.8248 - val_loss: 0.7126 - learning_rate: 0.0010
# Epoch 21/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 125s 100ms/step - accuracy: 0.8347 - loss: 0.4772 - val_accuracy: 0.8311 - val_loss: 0.6923 - learning_rate: 0.0010
# Epoch 22/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 126s 101ms/step - accuracy: 0.8624 - loss: 0.3876 - val_accuracy: 0.8421 - val_loss: 0.6819 - learning_rate: 5.0000e-04
# Epoch 23/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 142s 101ms/step - accuracy: 0.8663 - loss: 0.3706 - val_accuracy: 0.8451 - val_loss: 0.6780 - learning_rate: 5.0000e-04
# Epoch 24/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 128s 102ms/step - accuracy: 0.8699 - loss: 0.3617 - val_accuracy: 0.8475 - val_loss: 0.6697 - learning_rate: 5.0000e-04
# Epoch 25/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 127s 101ms/step - accuracy: 0.8741 - loss: 0.3446 - val_accuracy: 0.8468 - val_loss: 0.6912 - learning_rate: 5.0000e-04
# Epoch 26/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 126s 101ms/step - accuracy: 0.8797 - loss: 0.3319 - val_accuracy: 0.8446 - val_loss: 0.7362 - learning_rate: 5.0000e-04
# Epoch 27/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 128s 102ms/step - accuracy: 0.8922 - loss: 0.2936 - val_accuracy: 0.8493 - val_loss: 0.7319 - learning_rate: 2.5000e-04
# Epoch 28/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 128s 102ms/step - accuracy: 0.8956 - loss: 0.2851 - val_accuracy: 0.8499 - val_loss: 0.7630 - learning_rate: 2.5000e-04
# Epoch 29/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 128s 102ms/step - accuracy: 0.8969 - loss: 0.2788 - val_accuracy: 0.8485 - val_loss: 0.7784 - learning_rate: 2.5000e-04
# Epoch 30/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 128s 102ms/step - accuracy: 0.9022 - loss: 0.2644 - val_accuracy: 0.8484 - val_loss: 0.7886 - learning_rate: 2.5000e-04
# Epoch 31/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 129s 102ms/step - accuracy: 0.9025 - loss: 0.2636 - val_accuracy: 0.8492 - val_loss: 0.8124 - learning_rate: 2.5000e-04
# Epoch 32/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 121s 96ms/step - accuracy: 0.9075 - loss: 0.2456 - val_accuracy: 0.8508 - val_loss: 0.8065 - learning_rate: 1.2500e-04
# Epoch 33/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 121s 97ms/step - accuracy: 0.9104 - loss: 0.2383 - val_accuracy: 0.8497 - val_loss: 0.8163 - learning_rate: 1.2500e-04
# Epoch 34/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 121s 97ms/step - accuracy: 0.9134 - loss: 0.2340 - val_accuracy: 0.8523 - val_loss: 0.8242 - learning_rate: 1.2500e-04
# Epoch 35/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 122s 97ms/step - accuracy: 0.9132 - loss: 0.2323 - val_accuracy: 0.8519 - val_loss: 0.8047 - learning_rate: 1.2500e-04
# Epoch 36/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 122s 97ms/step - accuracy: 0.9152 - loss: 0.2287 - val_accuracy: 0.8531 - val_loss: 0.8132 - learning_rate: 1.2500e-04
# Epoch 37/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 133s 106ms/step - accuracy: 0.9184 - loss: 0.2176 - val_accuracy: 0.8517 - val_loss: 0.8318 - learning_rate: 6.2500e-05
# Epoch 38/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 126s 101ms/step - accuracy: 0.9203 - loss: 0.2128 - val_accuracy: 0.8522 - val_loss: 0.8497 - learning_rate: 6.2500e-05
# Epoch 39/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 124s 98ms/step - accuracy: 0.9190 - loss: 0.2170 - val_accuracy: 0.8520 - val_loss: 0.8423 - learning_rate: 6.2500e-05
# Epoch 40/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 123s 98ms/step - accuracy: 0.9204 - loss: 0.2112 - val_accuracy: 0.8510 - val_loss: 0.8568 - learning_rate: 6.2500e-05
# Epoch 41/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 140s 96ms/step - accuracy: 0.9193 - loss: 0.2164 - val_accuracy: 0.8504 - val_loss: 0.8501 - learning_rate: 6.2500e-05
# Epoch 42/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 122s 97ms/step - accuracy: 0.9226 - loss: 0.2078 - val_accuracy: 0.8509 - val_loss: 0.8492 - learning_rate: 3.1250e-05
# Epoch 43/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 123s 98ms/step - accuracy: 0.9231 - loss: 0.2041 - val_accuracy: 0.8520 - val_loss: 0.8648 - learning_rate: 3.1250e-05
# Epoch 44/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 122s 97ms/step - accuracy: 0.9235 - loss: 0.2066 - val_accuracy: 0.8513 - val_loss: 0.8552 - learning_rate: 3.1250e-05
# Epoch 45/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 123s 98ms/step - accuracy: 0.9254 - loss: 0.2024 - val_accuracy: 0.8510 - val_loss: 0.8686 - learning_rate: 3.1250e-05
# Epoch 46/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 123s 98ms/step - accuracy: 0.9240 - loss: 0.2035 - val_accuracy: 0.8523 - val_loss: 0.8699 - learning_rate: 3.1250e-05
# Epoch 47/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 122s 97ms/step - accuracy: 0.9248 - loss: 0.2032 - val_accuracy: 0.8521 - val_loss: 0.8649 - learning_rate: 1.5625e-05
# Epoch 48/80
# 1255/1255 ━━━━━━━━━━━━━━━━━━━━ 124s 98ms/step - accuracy: 0.9267 - loss: 0.1962 - val_accuracy: 0.8521 - val_loss: 0.8776 - learning_rate: 1.5625e-05

# %% [markdown]
# # Observations from model

# %% [markdown]
# ## Learning Curves
#
# Learning curves to track the progress of training and validation accuracy/loss over epochs.

# %%
import matplotlib.pyplot as plt

# Accuracy curves
plt.figure(figsize=(8, 5))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Loss curves
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Recognition Scores
#
# Reports both character and CAPTCHA accuracy.

# %%
# calculate accuracy
y_pred = model.predict(X_test)
decoded_pred = decode_array(np.argmax(y_pred, axis=1))
decoded_true = decode_array(np.argmax(y_test, axis=1))

pred_strings, true_strings = [], []
i = 0
for length in lengths_test:
  pred_strings.append(''.join(decoded_pred[i:i+length]))
  true_strings.append(''.join(decoded_true[i:i+length]))
  i += length

correct = sum(p == t for p, t in zip(pred_strings, true_strings))
captcha_acc = correct / len(lengths_test)

print(f"Captcha-level accuracy: {(captcha_acc*100):.4f}%")

char_acc = np.mean(decoded_pred == decoded_true)
print(f"Character-level accuracy: {(char_acc*100):.4f}%")
# Out:
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step
# Captcha-level accuracy: 50.2952%
# Character-level accuracy: 85.3119%

# %% [markdown]
# ## Confusion matrix
#
# Confusion matrix to show common misclassifications made by the model between predicted and true CAPTCHA data.

# %%
# Confusion matrix for one-hot class indices
cm = confusion_matrix(np.argmax(y_pred, axis=1), np.argmax(y_test, axis=1))

plt.figure(figsize=(14, 12))
sns.heatmap(cm, annot=False, cmap='Blues', xticklabels=CHARSET, yticklabels=CHARSET)
plt.title('Confusion Matrix (A-Z, 0-9)')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
